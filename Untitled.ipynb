# %%
from scipy import stats

# %%
import pandas as pd

# %%
data=pd.read_csv("oupeipipeizengjiabianl.csv")

# %%
data.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Unnamed: 0_x  AwayGoals_x  AwayHalfGoals_x  \
# 0           0             0             0            2                1
# 1           1             1             0            0                0
# 2           2             2             0            0                0
# 3           3             3             0            1                0
# 4           4             4             0            0                0
#
#   AwayName  AwayTeamId_x  ChuDraw_x  ChuLose_x  ChuWin_x       ...         \
# 0     亚特兰大           493        3.4       4.00       1.9       ...
# 1      法基克          1495        3.4       3.30       2.0       ...
# 2      法基克          1495        3.4       3.30       2.0       ...
# 3       邓迪           388        3.4       3.75       2.0       ...
# 4     阿尔梅利           483        3.1       3.75       2.1       ...
#
#   LoseOdds_y  MatchId_y            StartTime_y  WinOdds_y result    prowin  \
# ...

# %%
stats.ttest_ind(data["ChuDraw_x"],data["ChuDraw_y"])
# Out:
# Ttest_indResult(statistic=11.610150643530593, pvalue=3.9925762290922943e-30)
